# %%
list
# Out:
# list

# %%
c

# %%
L =[1,45,456,'sudh',True,345.456]

# %%
L[-1:5:-2]
# Out:
# []

# %%
L[-1:-5:-2]
# Out:
# [345.456, 'sudh']

# %%
L[1:6:-2]
# Out:
# []

# %%
L[1:6]
# Out:
# [45, 456, 'sudh', True, 345.456]

# %%
L[0:5:]
# Out:
# [1, 45, 456, 'sudh', True]

# %%
L[1:6]
# Out:
# [45, 456, 'sudh', True, 345.456]

# %%
L.append(676)

# %%
L
# Out:
# [1, 45, 456, 'sudh', True, 345.456, 676]

# %%
L.pop(5)
# Out:
# 345.456

# %%
str = "1,23,45,78,87"

# %%
list(str)+L
# Out:
# ['1',
#  ',',
#  '2',
#  '3',
#  ',',
#  '4',
#  '5',
#  ',',
#  '7',
#  '8',
#  ',',
#  '8',
#  '7',
#  1,
#  45,
#  456,
#  'sudh',
#  True,
#  676]

# %%
L[3][0]
# Out:
# 's'

# %%
L[3][0:2]
# Out:
# 'su'

# %%
L.insert(2,67)

# %%
L.pop(5)
# Out:
# 'sudh'

# %%
name =input("Enter your name:")
age =int(input("Enter your age"))
print("name:",name)
print("age:",age)
# Out:
# Enter your name:ANSH
# Enter your age19
# name: ANSH
# age: 19

# %% [markdown]
# X =                                                                                                                 M
