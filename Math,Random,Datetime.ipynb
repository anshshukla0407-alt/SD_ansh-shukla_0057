# %%
import math
num = 25
print(math.sqrt(num))
# Out:
# 5.0

# %%
print(math.pow(2,5))
# Out:
# 32.0

# %%
print(math.factorial(5))
# Out:
# 120

# %%
print(math.ceil(4.2))
# Out:
# 5

# %%
print(math.floor(4.9))
# Out:
# 4

# %%
print(abs(-50))
# Out:
# 50

# %%
print(math.gcd(24,36))
# Out:
# 12

# %%
print(math.lcm(12,18))
# Out:
# 36

# %%
print(math.pi)
# Out:
# 3.141592653589793

# %%
print(math.e)
# Out:
# 2.718281828459045

# %%
print(math.sin(math.radians(90)))
# Out:
# 1.0

# %%
print(math.tan(math.radians(45)))
# Out:
# 0.9999999999999999

# %%
print(math.log10(100))
# Out:
# 2.0

# %%
print(math.log(10))
# Out:
# 2.302585092994046

# %%
import random
print(random.randint(1,10))
# Out:
# 4

# %%
import random
otp = random.randint(100000,999999)
print("Your OTP is",otp)
# Out:
# Your OTP is 502394

# %%
print(random.random())
# Out:
# 0.06618236314316328

# %%
print(random.randrange(1,100))
# Out:
# 3

# %%
fruits=["Apple","Banana","Mango","Orange"]
print(random.choice(fruits))
# Out:
# Mango

# %%
numbers = [1,2,3,4,5]
random.shuffle(numbers)
print(numbers)
# Out:
# [3, 2, 4, 5, 1]

# %%
print(random.uniform(1,10))
# Out:
# 1.8501492217058018

# %%
print(random.choice([True,False]))
# Out:
# True

# %%
import datetime
print(datetime.datetime.now())
# Out:
# 2026-07-20 06:24:41.219898

# %%
print(datetime.date.today())
# Out:
# 2026-07-20

# %%
print(datetime.datetime.now().time())
# Out:
# 06:28:27.639455

# %%
print(datetime.datetime.now().year)
# Out:
# 2026

# %%
print(datetime.datetime.now().month)
# Out:
# 7

# %%
print(datetime.datetime.now().day)
# Out:
# 20

# %%
print(datetime.datetime.now().hour)
# Out:
# 6

# %%
print(datetime.datetime.now().minute)
# Out:
# 37

# %%
print(datetime.datetime.now().second)
# Out:
# 14

# %%
#custom
d = datetime.date(2026,7,19)
print(d)
# Out:
# 2026-07-19

# %%
import datetime
date1 = datetime.date(2026,7,19)
date2 = datetime.date(2026,8,19)
print(date2 - date1)
# Out:
# 31 days, 0:00:00

# %%
today = datetime.datetime.now()
print(today.strftime("%d-%m-%Y"))
# Out:
# 20-07-2026

# %%
now = datetime.datetime.now()
print(now.strftime("%H:%M:%S"))
# Out:
# 06:50:47

# %%
today = datetime.datetime.now()
print(today.strftime("%A"))
# Out:
# Monday

# %%
today = datetime.datetime.now()
print(today.strftime("%B"))
# Out:
# July

# %%
import datetime
usa_day = datetime.date.today()
usa_time = datetime.datetime.now().time()
print("DIGITAL CLOCK")
print("Today's Date in USA:",usa_day)
print("Current time in USA:",usa_time)
# Out:
# DIGITAL CLOCK
# Today's Date in USA: 2026-07-20
# Current time in USA: 08:32:14.720107
