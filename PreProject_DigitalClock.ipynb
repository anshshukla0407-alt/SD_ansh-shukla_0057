# %%
import time
from IPython.display import clear_output
from datetime import datetime

while True:
  clear_output(wait=True)
  current_time = datetime.now().strftime("%I:%M:%S %p")
  print("         DIGITAL CLOCK        ")
  print(current_time)
  time.sleep(1)
# Out:
#          DIGITAL CLOCK
# 08:45:05 AM
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_1262/1979342548.py in <cell line: 0>()
#       8   print("         DIGITAL CLOCK        ")
#       9   print(current_time)
# ---> 10   time.sleep(1)
#
# KeyboardInterrupt:

# %%
import time
from IPython.display import clear_output
from datetime import datetime
from zoneinfo import ZoneInfo
while True:
  clear_output(wait=True)
  ist_time = datetime.now(ZoneInfo("Asia/Kolkata"))
  print("         DIGITAL CLOCK       ")
  print("Date :", ist_time.strftime("%d-%m-%Y"))
  print("Day  :", ist_time.strftime("%A"))
  print("Time :", ist_time.strftime("%I:%M:%S %p"))
  print("Zone :", "Indian Standard Time (IST)")
  time.sleep(1)
# Out:
#          DIGITAL CLOCK
# Date : 20-07-2026
# Day  : Monday
# Time : 02:47:06 PM
# Zone : Indian Standard Time (IST)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_1262/2524316158.py in <cell line: 0>()
#      11   print("Time :", ist_time.strftime("%I:%M:%S %p"))
#      12   print("Zone :", "Indian Standard Time (IST)")
# ---> 13   time.sleep(1)
#      14
#
# KeyboardInterrupt:
