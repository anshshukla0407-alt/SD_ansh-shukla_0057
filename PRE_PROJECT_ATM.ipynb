# %%
l = [1,3,9]

# %%
sqr_l = [x**2 for x in l]
display(squared_l)
# Out:
# [1, 9, 81]

# %%
l =[]
for i in l:
  l.append(i**2)
  print(l)

# %%
l
# Out:
# []
# []

# %%
l1= ["sudha","skill","kumar","data science"]

# %%
[i.upper() for i in l1]
# Out:
# ['SUDHA', 'SKILL', 'KUMAR', 'DATA SCIENCE']

# %%
d ={"key1":1,"key2":2,"key":3,"key4":4}

# %%
{k:v**2 for k,v in d.items()}
# Out:
# {'key1': 1, 'key2': 4, 'key': 9, 'key4': 16}

# %%
d.items()
# Out:
# dict_items([('key1', 1), ('key2', 2), ('key', 3), ('key4', 4)])

# %%
d
# Out:
# {'key1': 1, 'key2': 2, 'key': 3, 'key4': 4}

# %%
{k:v for k,v in d.items() if v>1}
# Out:
# {'key2': 2, 'key': 3, 'key4': 4}

# %%
a =int(input("enter the no.1"))
b =int(input("enter the no.2"))
sum=0
sum=a+b
print(sum)
# Out:
# enter the no.155
# enter the no.245
# 100

# %%
def test2():
  return "this is my very first return"

# %%
test2
# Out:
# <function __main__.test2()>

# %%
test2()
# Out:
# 'this is my very first return'

# %%
def test3():
  return "sudh",23,345.56,[1,2,3]

# %%
test3()
# Out:
# ('sudh', 23, 345.56, [1, 2, 3])

# %%
def calc(a,b,c):
    if(c=="+"):
     print(a+b)
    elif(c=="-"):
     print(a-b)
    elif(c=="*"):
     print(a*b)
    elif(c=="/"):
     print(a/b)
    return "done"
n1=int(input("enter the no.1"))
n2=int(input("enter the no.2"))
op=input("enter the operator")
calc(n1,n2,op)
# Out:
# enter the no.170
# enter the no.220
# enter the operator*
# 1400
# 'done'

# %%
def deposit():
  pin = int(input("Enter PIN: "))
  if pin != customer["PIN"]:
    print("Invalid PIN")
  else:
    money=int(input("Enter amount to be deposited: "))
    customer["Amount"] = customer["Amount"] + money
def withdrawal():
  pin = int(input("Enter PIN: "))
  if pin != customer["PIN"]:
    print("Invalid PIN")
  else:
    money=int(input("Enter amount to be withdrawn: "))
    if customer["Amount"] < money:
      print("Not enough balance")
    else:
      customer["Amount"] = customer["Amount"] - money
      return customer["Amount"]
def amount():
  print(customer["Amount"])

def pin_change():
  pin = int(input("Enter PIN: "))
  if pin != customer["PIN"]:
    print("Invalid PIN")
  else:
    npin = int(input("Enter new PIN: "))
    n2pin = int(input("Confirm PIN"))
    if npin != n2pin:
      print("Not same")
    else:
      print("PIN changed succesfully")

customer = {"Card number" : 1234 , "PIN" : 789 , "Amount" : 4500 }
cnum = int(input("Enter Card number: "))
if cnum != customer["Card number"]:
  print("Invalid Card Number")
else:
  service = int(input("Enter service:\n 1-DEPOSIT \n 2-WITHDRAWAL \n 3-PIN CHANGE \n 4-AMOUNT CHECK \n "))
  if service == 1:
    deposit()
  elif service == 2:
    print("new amount :" ,withdrawal())
  elif service == 3:
    pin_change()
  elif service == 4:
    amount()
  else:
    print("Invalid choice")
# Out:
# Enter Card number: 1234
# Enter service:
#  1-DEPOSIT
#  2-WITHDRAWAL
#  3-PIN CHANGE
#  4-AMOUNT CHECK
#  4
# 4500

# %%
def wid():
    ENTER_AMOUNT=int(input("ENTER AMOUNT"))
    print("VALIDATING AMOUNT")
    if D["balance"]> ENTER_AMOUNT:
        print("SUFFICIENT BALANCE")
        print("AMOUNT DEBITED:",  ENTER_AMOUNT)
        print("WITHDRAWL SUCCESSFUL")
        print("AMOUNT LEFT:",D["balance"]- ENTER_AMOUNT)
        print(" CARD EJECTED")
    else:
        print("INSUFFICIENT BALANCE")
        print(" CARD EJECTED")
def dep():
    AMOUNT=int(input("ENTER AMOUNT TO BE DEPOSITED:"))
    print("CASH DETECTED")
    print("CASH DEPOSITED SUCCESSFULLY!!!")
    print("AMOUNT:",AMOUNT,"IS CREDITED TO YOUR ACCOUNT")
    print(" CARD EJECTED")
def inq():
    print("BALANCE IN YOUR ACCOUNT:",D["balance"])
    print(" CARD EJECTED")
D={"acc_no":45457532,"balance":50000,"pin-no":45663}
print("INSERT CARD")
CARD_NO=int(input("ENTER CARD NO."))
PIN_NO=int(input("ENTER PIN NO."))
print(" SERVICES:")
print("WITHDRAWL")
print("DEPOSIT")
print("BALANCE ENQUIRY")
print("_EXIT")
SERVICES=input("ENTER SERVICES")
if SERVICES=="WITHDRAWL":
    wid()

elif SERVICES=="DEPOSIT":
    dep()

elif SERVICES=="BALANCE INQUIRY":
    inq()
elif SERVICES=="EXIT":
    print("CARD EJECTED")
    print("THANK YOU!!")
else:
    print("INVALID CHOICE")
    print("EJECT CARD")
# Out:
# INSERT CARD
# ENTER CARD NO.4050
# ENTER PIN NO.4050
#  SERVICES:
# WITHDRAWL
# DEPOSIT
# BALANCE ENQUIRY
# _EXIT
# ENTER SERVICESWITHDRAWAL
# INVALID CHOICE
# EJECT CARD

# %%
print("-----------Welcome to our Bank-----------\n")
print("----Please add your bank details to avail our services----\n")
name=str(input("Enter the name of your bank"))
print("----Please enter your card----")
print("----Please enter your pin----")
ac_num=int(input("Enter the Account Number\n"))

print("---Enter 1 to select Savings Account---\n")
print("---Enter 2 to select current account---\n")
print("---Enter 3 for other main type---\n")
print("---Enter 4 for other account type---\n")


ac_num2=(input("Choose the account type\n"))
def choice1(a):
  if a==1:
    print("redirecting to your savings account........\n")
  elif a==2:
    print("redirecting to  your current account.......\n")
  elif a==3:
    print("redirecting to your main account.......\n ")
  elif a==4:
    print("redirecting to......\n")
  else:
    print("!...Invalid Choice Selected...!\n")
choice1(ac_num2)

print("!..Please select any of the services to continue..!")
print("---Enter 1 for CASH WITHDRAWL---\n")
print("---Enter 2 for SEND MONEY---\n")
print("---Enter 3 for CHECK YOUR BALANCE---\n")
print("---Enter 4 for ADD MONEY---\n")

ac_num3=int(input("....PLEASE ENTER THE SERVICE FROM ABOVE...."))
def choice2(b):
  bankSummary=99999
  user=100000

  if b==1:

      ac_num3=int(input("ENTER THE AMOUNT FOR WITHDRAWL\n"))
      if b<bankSummary:
         print("-----ENTER THE PIN----\n")
         print("!...REMAINING BALANCE...!"+" " +str(bankSummary-ac_num3))
         print("PLEASE COLLECT THE CASH\n")
         user=user-ac_num3
      else:
         print("INSUFFICIENT BALANCE\n")
  elif ac_num2==2:
      ac_num4=int(input("ENTER THE AMOUNT TO SEND\n"))
      if ac_num4<userBalance:
         print("----TRANSACTION SUCCESSFULL\n")
      else:
         print("INSUFFICIENT BALANCE\n")

  elif ac_num2==3:
       print(userBalance)

  else:
    ac_num5=int(input("ENTER THE AMOUNT TO BE ADDED IN YOUR ACCOUNT\n"))
    user+=ac_num5
    print(userg)
choice2(ac_num3)



print("*......YOU HAVE SUCCESSFULLY COMPLETED YOUR TRANSACTION.....*")
# Out:
# -----------Welcome to our Bank-----------
#
# ----Please add your bank details to avail our services----
#
# Enter the name of your bankBOB
# ----Please enter your card----
# ----Please enter your pin----
# Enter the Account Number
# 7777
# ---Enter 1 to select Savings Account---
#
# ---Enter 2 to select current account---
#
# ---Enter 3 for other main type---
#
# ---Enter 4 for other account type---
#
# Choose the account type
# 1
# !...Invalid Choice Selected...!
#
# !..Please select any of the services to continue..!
# ---Enter 1 for CASH WITHDRAWL---
#
# ---Enter 2 for SEND MONEY---
#
# ---Enter 3 for CHECK YOUR BALANCE---
#
# ---Enter 4 for ADD MONEY---
#
# ....PLEASE ENTER THE SERVICE FROM ABOVE....1
# ENTER THE AMOUNT FOR WITHDRAWL
# 100000
# -----ENTER THE PIN----
#
# !...REMAINING BALANCE...! -1
# PLEASE COLLECT THE CASH
#
# *......YOU HAVE SUCCESSFULLY COMPLETED YOUR TRANSACTION.....*
